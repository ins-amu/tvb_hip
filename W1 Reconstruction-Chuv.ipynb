# %% [markdown]
# # Reconstruction
#
# Before working with patient data in TVB, an anatomical reconstruction needs to be performed, which uses FreeSurfer and MRtrix3 to construct the brain regions and connectivity.

# %% [markdown]
# ## Running the pipeline
#
# The pipeline is included with the TVB-HIP app. You may wish to use your own license or the one provided with the app:

# %%
# !cp license.txt /apps/tvb-hip/freesurfer/.license

# %% [markdown]
# Next we create a subject folder `fs` and initiate the pipeline with external input data, currently provided via the Docker volume mount at `/data/raw`. *This will be updated to reflect the HIP data structure once we are able to deploy within the HIP infrastructure.*

# %% [markdown]
# The pipeline run itself can take several hours to complete, and the log output is verbose, so please be patient.
#
# *In a future iteration of the notebook, a clearer GUI will provide a progress bar and visualization.*

# %%
# !make -C tvb-pipeline SUBJECTS_DIR=/data/fs SUBJECT=rechuv T1=/data/chuv/mri/t1.nii.gz DWI=/data/chuv/mri/ep2d_diff_MGHDTI2_tra48x2_12 fs-recon resamp-anat conn tvb
# Out:
# make: Entering directory '/work/tvb-pipeline'
# tmp=$(mktemp -d) && mrconvert /data/chuv/mri/t1.nii.gz $tmp/T1.nii.gz && recon-all -s rechuv -i $tmp/T1.nii.gz  && rm -r $tmp
# mrconvert: [100%] uncompressing image "/data/chuv/mri/t1.nii.gz"[0K
# mrconvert: [100%] copying from "/data/chuv/mri/t1.nii.gz" to "/tmp/tmp.CK4MkBy0zh/T1.nii.gz"[0K
# mrconvert: [100%] compressing image "/tmp/tmp.CK4MkBy0zh/T1.nii.gz"[0K
# Subject Stamp: freesurfer-linux-ubuntu18_x86_64-7.2.0-20210721-aa8f76b
# Current Stamp: freesurfer-linux-ubuntu18_x86_64-7.2.0-20210721-aa8f76b
# INFO: SUBJECTS_DIR is /data/fs
# Actual FREESURFER_HOME /apps/tvb-hip/freesurfer
# Linux ad03c415e0ad 5.10.16.3-microsoft-standard-WSL2 #1 SMP Fri Apr 2 22:23:49 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux
# /data/fs/rechuv
#
#  mri_convert /tmp/tmp.CK4MkBy0zh/T1.nii.gz /data/fs/rechuv/mri/orig/001.mgz
#
# mri_convert /tmp/tmp.CK4MkBy0zh/T1.nii.gz /data/fs/rechuv/mri/orig/001.mgz
# reading from /tmp/tmp.CK4MkBy0zh/T1.nii.gz...
# INFO: this is an unsiged short. I'll try to read it, but
#       it might not work if there are values over 32k
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.00096729, -0.995725, -0.0923655)
# j_ras = (-0.0104271, 0.0923706, -0.99567)
# k_ras = (0.999945, 1.31073e-09, -0.0104718)
# writing to /data/fs/rechuv/mri/orig/001.mgz...
# /data/fs/rechuv/mri/transforms /data/fs/rechuv
# /data/fs/rechuv
#
# Started at Mon Jan 10 16:07:47 UTC 2022
# Ended   at Mon Jan 10 16:07:49 UTC 2022
# #@#%# recon-all-run-time-hours 0.001
# recon-all -s rechuv finished without error at Mon Jan 10 16:07:49 UTC 2022
# done
# recon-all -s rechuv -all -parallel -openmp 8
# Subject Stamp: freesurfer-linux-ubuntu18_x86_64-7.2.0-20210721-aa8f76b
# Current Stamp: freesurfer-linux-ubuntu18_x86_64-7.2.0-20210721-aa8f76b
# INFO: SUBJECTS_DIR is /data/fs
# Actual FREESURFER_HOME /apps/tvb-hip/freesurfer
# -rw-rw-r-- 1 root root 30280 Jan 10 16:07 /data/fs/rechuv/scripts/recon-all.log
# Linux ad03c415e0ad 5.10.16.3-microsoft-standard-WSL2 #1 SMP Fri Apr 2 22:23:49 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux
# #--------------------------------------------
# #@# MotionCor Mon Jan 10 16:07:50 UTC 2022
# Found 1 runs
# /data/fs/rechuv/mri/orig/001.mgz
# Checking for (invalid) multi-frame inputs...
# Only one run found so motion
# correction will not be performed. I'll
# copy the run to rawavg and continue.
#
#  cp /data/fs/rechuv/mri/orig/001.mgz /data/fs/rechuv/mri/rawavg.mgz
#
# /data/fs/rechuv
#
#  mri_convert /data/fs/rechuv/mri/rawavg.mgz /data/fs/rechuv/mri/orig.mgz --conform
#
# mri_convert /data/fs/rechuv/mri/rawavg.mgz /data/fs/rechuv/mri/orig.mgz --conform
# reading from /data/fs/rechuv/mri/rawavg.mgz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.00096729, -0.995725, -0.0923655)
# j_ras = (-0.0104271, 0.0923706, -0.99567)
# k_ras = (0.999945, 1.31073e-09, -0.0104718)
# changing data type from short to uchar (noscale = 0)...
# MRIchangeType: Building histogram 0 1540 1000, flo=0, fhi=0.999, dest_type=0
# Reslicing using trilinear interpolation
# writing to /data/fs/rechuv/mri/orig.mgz...
#
#  mri_add_xform_to_header -c /data/fs/rechuv/mri/transforms/talairach.xfm /data/fs/rechuv/mri/orig.mgz /data/fs/rechuv/mri/orig.mgz
#
# INFO: extension is mgz
# #--------------------------------------------
# #@# Talairach Mon Jan 10 16:07:56 UTC 2022
# /data/fs/rechuv/mri
#
#  mri_nu_correct.mni --no-rescale --i orig.mgz --o orig_nu.mgz --ants-n4 --n 1 --proto-iters 1000 --distance 50
#
# /usr/bin/bc
# /data/fs/rechuv/mri
# /apps/tvb-hip/freesurfer/bin/mri_nu_correct.mni
# --no-rescale --i orig.mgz --o orig_nu.mgz --ants-n4 --n 1 --proto-iters 1000 --distance 50
# nIters 1
# mri_nu_correct.mni 7.2.0
# Linux ad03c415e0ad 5.10.16.3-microsoft-standard-WSL2 #1 SMP Fri Apr 2 22:23:49 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux
# Mon Jan 10 16:07:56 UTC 2022
# tmpdir is ./tmp.mri_nu_correct.mni.619
# cd /data/fs/rechuv/mri
# AntsN4BiasFieldCorrectionFs -i orig.mgz -o ./tmp.mri_nu_correct.mni.619/nu0.mgz --dtype uchar
# AntsN4BiasFieldCorrectionFs done
# mri_convert ./tmp.mri_nu_correct.mni.619/nu0.mgz orig_nu.mgz --like orig.mgz --conform
# mri_convert ./tmp.mri_nu_correct.mni.619/nu0.mgz orig_nu.mgz --like orig.mgz --conform
# reading from ./tmp.mri_nu_correct.mni.619/nu0.mgz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.00867e-11, -9.31323e-10)
# j_ras = (-9.31323e-10, 7.46431e-09, -1)
# k_ras = (-1.11429e-10, 1, -7.46587e-09)
# INFO: transform src into the like-volume: orig.mgz
# writing to orig_nu.mgz...
#
#
# Mon Jan 10 16:11:22 UTC 2022
# mri_nu_correct.mni done
#
#  talairach_avi --i orig_nu.mgz --xfm transforms/talairach.auto.xfm
#
# talairach_avi log file is transforms/talairach_avi.log...
# Started at Mon Jan 10 16:11:22 UTC 2022
# Ended   at Mon Jan 10 16:11:41 UTC 2022
# talairach_avi done
#
#  cp transforms/talairach.auto.xfm transforms/talairach.xfm
#
# lta_convert --src orig.mgz --trg /apps/tvb-hip/freesurfer/average/mni305.cor.mgz --inxfm transforms/talairach.xfm --outlta transforms/talairach.xfm.lta --subject fsaverage --ltavox2vox
# 7.2.0
#
# --src: orig.mgz src image (geometry).
# --trg: /apps/tvb-hip/freesurfer/average/mni305.cor.mgz trg image (geometry).
# --inmni: transforms/talairach.xfm input MNI/XFM transform.
# --outlta: transforms/talairach.xfm.lta output LTA.
# --s: fsaverage subject name
# --ltavox2vox: output LTA as VOX_TO_VOX transform.
#  LTA read, type : 1
#  1.14845   0.03052   0.00363  -12.68826;
#  0.00303   1.17506   0.11896  -55.15824;
#  0.02682  -0.07880   1.15339  -48.94182;
#  0.00000   0.00000   0.00000   1.00000;
# setting subject to fsaverage
# Writing  LTA to file transforms/talairach.xfm.lta...
# lta_convert successful.
# /data/fs/rechuv/mri/transforms /data/fs/rechuv/mri
# /data/fs/rechuv/mri
# #--------------------------------------------
# #@# Talairach Failure Detection Mon Jan 10 16:11:43 UTC 2022
# /data/fs/rechuv/mri
#
#  talairach_afd -T 0.005 -xfm transforms/talairach.xfm
#
# talairach_afd: Talairach Transform: transforms/talairach.xfm OK (p=0.8004, pval=0.8469 >= threshold=0.0050)
#
#  awk -f /apps/tvb-hip/freesurfer/bin/extract_talairach_avi_QA.awk /data/fs/rechuv/mri/transforms/talairach_avi.log
#
#
#  tal_QC_AZS /data/fs/rechuv/mri/transforms/talairach_avi.log
#
# TalAviQA: 0.97352
# z-score: -1
# #--------------------------------------------
# #@# Nu Intensity Correction Mon Jan 10 16:11:43 UTC 2022
#
#  mri_nu_correct.mni --i orig.mgz --o nu.mgz --uchar transforms/talairach.xfm --n 2 --ants-n4
#
# /usr/bin/bc
# /data/fs/rechuv/mri
# /apps/tvb-hip/freesurfer/bin/mri_nu_correct.mni
# --i orig.mgz --o nu.mgz --uchar transforms/talairach.xfm --n 2 --ants-n4
# nIters 2
# mri_nu_correct.mni 7.2.0
# Linux ad03c415e0ad 5.10.16.3-microsoft-standard-WSL2 #1 SMP Fri Apr 2 22:23:49 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux
# Mon Jan 10 16:11:43 UTC 2022
# tmpdir is ./tmp.mri_nu_correct.mni.850
# cd /data/fs/rechuv/mri
# AntsN4BiasFieldCorrectionFs -i orig.mgz -o ./tmp.mri_nu_correct.mni.850/nu0.mgz --dtype uchar
# AntsN4BiasFieldCorrectionFs done
# mri_binarize --i ./tmp.mri_nu_correct.mni.850/nu0.mgz --min -1 --o ./tmp.mri_nu_correct.mni.850/ones.mgz
#
# 7.2.0
# cwd /data/fs/rechuv/mri
# cmdline mri_binarize --i ./tmp.mri_nu_correct.mni.850/nu0.mgz --min -1 --o ./tmp.mri_nu_correct.mni.850/ones.mgz
# sysname  Linux
# hostname ad03c415e0ad
# machine  x86_64
# user     root
#
# input      ./tmp.mri_nu_correct.mni.850/nu0.mgz
# frame      0
# nErode3d   0
# nErode2d   0
# output     ./tmp.mri_nu_correct.mni.850/ones.mgz
# Binarizing based on threshold
# min        -1
# max        +infinity
# binval        1
# binvalnot     0
# fstart = 0, fend = 0, nframes = 1
# Starting parallel 1
# Found 16777216 values in range
# Counting number of voxels in first frame
# Found 16777215 voxels in final mask
# Writing output to ./tmp.mri_nu_correct.mni.850/ones.mgz
# Count: 16777215 16777215.000000 16777216 99.999994
# mri_binarize done
# mri_segstats --id 1 --seg ./tmp.mri_nu_correct.mni.850/ones.mgz --i orig.mgz --sum ./tmp.mri_nu_correct.mni.850/sum.junk --avgwf ./tmp.mri_nu_correct.mni.850/input.mean.dat
#
# 7.2.0
# cwd
# cmdline mri_segstats --id 1 --seg ./tmp.mri_nu_correct.mni.850/ones.mgz --i orig.mgz --sum ./tmp.mri_nu_correct.mni.850/sum.junk --avgwf ./tmp.mri_nu_correct.mni.850/input.mean.dat
# sysname  Linux
# hostname ad03c415e0ad
# machine  x86_64
# user     root
# whitesurfname  white
# UseRobust  0
# Loading ./tmp.mri_nu_correct.mni.850/ones.mgz
# Loading orig.mgz
# Voxel Volume is 1 mm^3
# Generating list of segmentation ids
# Found   1 segmentations
# Computing statistics for each segmentation
#
# Reporting on   1 segmentations
# Using PrintSegStat
# Computing spatial average of each frame
#   0
# Writing to ./tmp.mri_nu_correct.mni.850/input.mean.dat
# mri_segstats done
# mri_segstats --id 1 --seg ./tmp.mri_nu_correct.mni.850/ones.mgz --i ./tmp.mri_nu_correct.mni.850/nu0.mgz --sum ./tmp.mri_nu_correct.mni.850/sum.junk --avgwf ./tmp.mri_nu_correct.mni.850/output.mean.dat
#
# 7.2.0
# cwd
# cmdline mri_segstats --id 1 --seg ./tmp.mri_nu_correct.mni.850/ones.mgz --i ./tmp.mri_nu_correct.mni.850/nu0.mgz --sum ./tmp.mri_nu_correct.mni.850/sum.junk --avgwf ./tmp.mri_nu_correct.mni.850/output.mean.dat
# sysname  Linux
# hostname ad03c415e0ad
# machine  x86_64
# user     root
# whitesurfname  white
# UseRobust  0
# Loading ./tmp.mri_nu_correct.mni.850/ones.mgz
# Loading ./tmp.mri_nu_correct.mni.850/nu0.mgz
# Voxel Volume is 1 mm^3
# Generating list of segmentation ids
# Found   1 segmentations
# Computing statistics for each segmentation
#
# Reporting on   1 segmentations
# Using PrintSegStat
# Computing spatial average of each frame
#   0
# Writing to ./tmp.mri_nu_correct.mni.850/output.mean.dat
# mri_segstats done
# mris_calc -o ./tmp.mri_nu_correct.mni.850/nu0.mgz ./tmp.mri_nu_correct.mni.850/nu0.mgz mul 1.87160510088307600222
# Saving result to './tmp.mri_nu_correct.mni.850/nu0.mgz' (type = MGH )                       [ ok ]
# mri_convert ./tmp.mri_nu_correct.mni.850/nu0.mgz nu.mgz --like orig.mgz
# mri_convert ./tmp.mri_nu_correct.mni.850/nu0.mgz nu.mgz --like orig.mgz
# reading from ./tmp.mri_nu_correct.mni.850/nu0.mgz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.00867e-11, -9.31323e-10)
# j_ras = (-9.31323e-10, 7.46431e-09, -1)
# k_ras = (-1.11429e-10, 1, -7.46587e-09)
# INFO: transform src into the like-volume: orig.mgz
# writing to nu.mgz...
# mri_make_uchar nu.mgz transforms/talairach.xfm nu.mgz
# type change took 0 minutes and 5 seconds.
# mapping (13, 173) to ( 3, 110)
#
#
# Mon Jan 10 16:15:19 UTC 2022
# mri_nu_correct.mni done
#
#  mri_add_xform_to_header -c /data/fs/rechuv/mri/transforms/talairach.xfm nu.mgz nu.mgz
#
# INFO: extension is mgz
# #--------------------------------------------
# #@# Intensity Normalization Mon Jan 10 16:15:20 UTC 2022
# /data/fs/rechuv/mri
#
#  mri_normalize -g 1 -seed 1234 -mprage nu.mgz T1.mgz
#
# using max gradient = 1.000
# setting seed for random number genererator to 1234
# assuming input volume is MGH (Van der Kouwe) MP-RAGE
# reading mri_src from nu.mgz...
# normalizing image...
# NOT doing gentle normalization with control points/label
# talairach transform
#  1.14845   0.03052   0.00363  -12.68826;
#  0.00303   1.17506   0.11896  -55.15824;
#  0.02682  -0.07880   1.15339  -48.94182;
#  0.00000   0.00000   0.00000   1.00000;
# processing without aseg, no1d=0
# MRInormInit():
# INFO: Modifying talairach volume c_(r,a,s) based on average_305
# MRInormalize():
# MRIsplineNormalize(): npeaks = 20
# Starting OpenSpline(): npoints = 20
# building Voronoi diagram...
# performing soap bubble smoothing, sigma = 8...
#
# Iterating 2 times
# ---------------------------------
# 3d normalization pass 1 of 2
# white matter peak found at 110
# white matter peak found at 110
# gm peak at 62 (62), valley at 25 (25)
# csf peak at 10, setting threshold to 44
# building Voronoi diagram...
# performing soap bubble smoothing, sigma = 8...
# ---------------------------------
# 3d normalization pass 2 of 2
# white matter peak found at 110
# white matter peak found at 110
# gm peak at 62 (62), valley at 21 (21)
# csf peak at 10, setting threshold to 44
# building Voronoi diagram...
# performing soap bubble smoothing, sigma = 8...
# Done iterating ---------------------------------
# writing output to T1.mgz
# 3D bias adjustment took 1 minutes and 6 seconds.
# #--------------------------------------------
# #@# Skull Stripping Mon Jan 10 16:16:27 UTC 2022
# /data/fs/rechuv/mri
#
#  mri_em_register -skull nu.mgz /apps/tvb-hip/freesurfer/average/RB_all_withskull_2020_01_02.gca transforms/talairach_with_skull.lta
#
# aligning to atlas containing skull, setting unknown_nbr_spacing = 5
#
# == Number of threads available to mri_em_register for OpenMP = 8 ==
# reading 1 input volumes...
# logging results to talairach_with_skull.log
# reading '/apps/tvb-hip/freesurfer/average/RB_all_withskull_2020_01_02.gca'...
# GCAread took 0 minutes and 1 seconds.
# average std = 23.0   using min determinant for regularization = 52.8
# 0 singular and 9205 ill-conditioned covariance matrices regularized
# reading 'nu.mgz'...
# freeing gibbs priors...done.
# accounting for voxel sizes in initial transform
# bounding unknown intensity as < 8.9 or > 556.0
# total sample mean = 77.3 (1403 zeros)
# ************************************************
# spacing=8, using 3292 sample points, tol=1.00e-05...
# ************************************************
# register_mri: find_optimal_transform
# find_optimal_transform: nsamples 3292, passno 0, spacing 8
# resetting wm mean[0]: 100 --> 108
# resetting gm mean[0]: 61 --> 61
# input volume #1 is the most T1-like
# using real data threshold=8.0
# skull bounding box = (52, 37, 24) --> (220, 245, 209)
# finding center of left hemi white matter
# using (108, 106, 117) as brain centroid of Right_Cerebral_White_Matter...
# MRImask(): AllowDiffGeom = 1
# mean wm in atlas = 108, using box (87,80,94) --> (128, 131,139) to find MRI wm
# before smoothing, mri peak at 107
# robust fit to distribution - 107 +- 4.6
# after smoothing, mri peak at 107, scaling input intensities by 1.009
# scaling channel 0 by 1.00935
# initial log_p = -4.308
# ************************************************
# First Search limited to translation only.
# ************************************************
# max log p =    -4.311357 @ (0.000, 0.000, 0.000)
# max log p =    -4.253515 @ (-5.263, 5.263, -5.263)
# max log p =    -4.234317 @ (2.632, -2.632, 2.632)
# max log p =    -4.218666 @ (-1.316, 1.316, -1.316)
# max log p =    -4.202623 @ (-0.658, -3.289, -3.289)
# max log p =    -4.202623 @ (0.000, 0.000, 0.000)
# max log p =    -4.202623 @ (0.000, 0.000, 0.000)
# max log p =    -4.202623 @ (0.000, 0.000, 0.000)
# Found translation: (-4.6, 0.7, -7.2): log p = -4.203
# ****************************************
# Nine parameter search.  iteration 0 nscales = 0 ...
# ****************************************
# Result so far: scale 1.000: max_log_p=-3.935, old_max_log_p =-4.203 (thresh=-4.2)
#  1.06375   0.00000   0.00000  -12.87413;
#  0.00000   1.22567   0.16136  -34.38319;
#  0.00000  -0.13885   1.05465   4.12162;
#  0.00000   0.00000   0.00000   1.00000;
# iteration took 0 minutes and 13 seconds.
# ****************************************
# Nine parameter search.  iteration 1 nscales = 0 ...
# ****************************************
# Result so far: scale 1.000: max_log_p=-3.935, old_max_log_p =-3.935 (thresh=-3.9)
#  1.06375   0.00000   0.00000  -12.87413;
#  0.00000   1.22567   0.16136  -34.38319;
#  0.00000  -0.13885   1.05465   4.12162;
#  0.00000   0.00000   0.00000   1.00000;
# reducing scale to 0.2500
# iteration took 0 minutes and 12 seconds.
# ****************************************
# Nine parameter search.  iteration 2 nscales = 1 ...
# ****************************************
# Result so far: scale 0.250: max_log_p=-3.853, old_max_log_p =-3.935 (thresh=-3.9)
#  1.08311  -0.00072   0.03684  -17.77944;
#  0.00000   1.18727   0.05246  -16.55737;
# -0.03415  -0.02132   1.08381  -8.11773;
#  0.00000   0.00000   0.00000   1.00000;
# iteration took 0 minutes and 11 seconds.
# ****************************************
# Nine parameter search.  iteration 3 nscales = 1 ...
# ****************************************
# Result so far: scale 0.250: max_log_p=-3.853, old_max_log_p =-3.853 (thresh=-3.8)
#  1.08311  -0.00072   0.03684  -17.77944;
#  0.00000   1.18727   0.05246  -16.55737;
# -0.03415  -0.02132   1.08381  -8.11773;
#  0.00000   0.00000   0.00000   1.00000;
# reducing scale to 0.0625
# iteration took 0 minutes and 11 seconds.
# ****************************************
# Nine parameter search.  iteration 4 nscales = 2 ...
# ****************************************
# Result so far: scale 0.062: max_log_p=-3.838, old_max_log_p =-3.853 (thresh=-3.8)
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00884   1.18723   0.05276  -17.24945;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
# iteration took 0 minutes and 11 seconds.
# ****************************************
# Nine parameter search.  iteration 5 nscales = 2 ...
# ****************************************
# Result so far: scale 0.062: max_log_p=-3.837, old_max_log_p =-3.838 (thresh=-3.8)
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00886   1.19001   0.05288  -17.62295;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
# min search scale 0.025000 reached
# ***********************************************
# Computing MAP estimate using 3292 samples...
# ***********************************************
# dt = 5.00e-06, momentum=0.80, tol=1.00e-05
# l_intensity = 1.0000
# Aligning input volume to GCA...
# Transform matrix
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00886   1.19001   0.05288  -17.62295;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
# nsamples 3292
# Quasinewton: input matrix
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00886   1.19001   0.05288  -17.62295;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
#  IFLAG= -1  LINE SEARCH FAILED. SEE DOCUMENTATION OF ROUTINE MCSRCH ERROR RETURN OF LINE SEARCH: INFO= 3 POSSIBLE CAUSES: FUNCTION OR GRADIENT ARE INCORRECT OR INCORRECT TOLERANCESoutof QuasiNewtonEMA: 008: -log(p) =   -0.0  tol 0.000010
# Resulting transform:
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00886   1.19001   0.05288  -17.62295;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
#
# pass 1, spacing 8: log(p) = -3.837 (old=-4.308)
# transform before final EM align:
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00886   1.19001   0.05288  -17.62295;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
#
# **************************************************
#  EM alignment process ...
#  Computing final MAP estimate using 364986 samples.
# **************************************************
# dt = 5.00e-06, momentum=0.80, tol=1.00e-07
# l_intensity = 1.0000
# Aligning input volume to GCA...
# Transform matrix
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00886   1.19001   0.05288  -17.62295;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
# nsamples 364986
# Quasinewton: input matrix
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00886   1.19001   0.05288  -17.62295;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
#  IFLAG= -1  LINE SEARCH FAILED. SEE DOCUMENTATION OF ROUTINE MCSRCH ERROR RETURN OF LINE SEARCH: INFO= 6 POSSIBLE CAUSES: FUNCTION OR GRADIENT ARE INCORRECT OR INCORRECT TOLERANCESoutof QuasiNewtonEMA: 010: -log(p) =    4.2  tol 0.000000
# final transform:
#  1.08054  -0.01043   0.03624  -16.13275;
#  0.00886   1.19001   0.05288  -17.62295;
# -0.03436  -0.02140   1.08762  -8.05754;
#  0.00000   0.00000   0.00000   1.00000;
#
# writing output transformation to transforms/talairach_with_skull.lta...
# #VMPC# mri_em_register VmPeak  837324
# FSRUNTIME@ mri_em_register  0.0308 hours 8 threads
# registration took 1 minutes and 51 seconds.
#
#  mri_watershed -T1 -brain_atlas /apps/tvb-hip/freesurfer/average/RB_all_withskull_2020_01_02.gca transforms/talairach_with_skull.lta T1.mgz brainmask.auto.mgz
#
#
# Mode:          T1 normalized volume
# Mode:          Use the information of atlas (default parms, --help for details)
#
# *********************************************************
# The input file is T1.mgz
# The output file is brainmask.auto.mgz
# Weighting the input with atlas information before watershed
#
# *************************WATERSHED**************************
# Sorting...
#       first estimation of the COG coord: x=127 y=106 z=117 r=81
#       first estimation of the main basin volume: 2270608 voxels
#       Looking for seedpoints
#         2 found in the cerebellum
#         16 found in the rest of the brain
#       global maximum in x=106, y=90, z=81, Imax=255
#       CSF=12, WM_intensity=110, WM_VARIANCE=5
#       WM_MIN=110, WM_HALF_MIN=110, WM_HALF_MAX=110, WM_MAX=110
#       preflooding height equal to 10 percent
# done.
# Analyze...
#
#       main basin size=8676384964 voxels, voxel volume =1.000
#                      = 8676384964 mmm3 = 8676384.768 cm3
# done.
# PostAnalyze...Basin Prior
#  35 basins merged thanks to atlas
#       ***** 0 basin(s) merged in 1 iteration(s)
#       ***** 0 voxel(s) added to the main basin
# done.
# Weighting the input with prior template
#
# ****************TEMPLATE DEFORMATION****************
#
#       second estimation of the COG coord: x=127,y=110, z=109, r=9156 iterations
# ^^^^^^^^ couldn't find WM with original limits - expanding ^^^^^^
#
#    GLOBAL      CSF_MIN=1, CSF_intensity=2, CSF_MAX=15 , nb = 43416
#   RIGHT_CER    CSF_MIN=1, CSF_intensity=2, CSF_MAX=20 , nb = 3168
#   LEFT_CER     CSF_MIN=1, CSF_intensity=2, CSF_MAX=10 , nb = 2826
#  RIGHT_BRAIN   CSF_MIN=1, CSF_intensity=2, CSF_MAX=14 , nb = 18702
#  LEFT_BRAIN    CSF_MIN=1, CSF_intensity=2, CSF_MAX=16 , nb = 18324
#     OTHER      CSF_MIN=4, CSF_intensity=12, CSF_MAX=71 , nb = 396
#  Problem with the least square interpolation in GM_MIN calculation.
#  Problem with the least square interpolation in GM_MIN calculation.
#  (2) Problem with the least square interpolation in GM_MIN calculation.
#
#                      CSF_MAX  TRANSITION  GM_MIN  GM
#     GLOBAL
#   before analyzing :    15,      23,        41,   69
#   after  analyzing :    15,      35,        41,   43
#    RIGHT_CER
#   before analyzing :    20,      24,        37,   81
#   after  analyzing :    20,      32,        37,   44
#    LEFT_CER
#   before analyzing :    10,      18,        48,   76
#   after  analyzing :    10,      38,        48,   47
#   RIGHT_BRAIN
#   before analyzing :    14,      22,        42,   69
#   after  analyzing :    14,      35,        42,   43
#   LEFT_BRAIN
#   before analyzing :    16,      22,        38,   71
#   after  analyzing :    16,      32,        38,   41
#      OTHER
#   before analyzing :    71,      3,        0,   2
#   after  analyzing :    3,      17,        25,   19
#       mri_strip_skull: done peeling brain
#       highly tesselated surface with 10242 vertices
#       matching...56 iterations
#
# *********************VALIDATION*********************
# curvature mean = -0.014, std = 0.010
# curvature mean = 67.507, std = 5.986
#
# No Rigid alignment: -atlas Mode Off (basic atlas / no registration)
#       before rotation: sse = 3.26, sigma = 5.69
#       after  rotation: sse = 3.26, sigma = 5.69
# Localization of inacurate regions: Erosion-Dilation steps
#       the sse mean is  3.54, its var is  5.01
#       before Erosion-Dilatation  0.72% of inacurate vertices
#       after  Erosion-Dilatation  0.00% of inacurate vertices
#       Validation of the shape of the surface done.
# Scaling of atlas fields onto current surface fields
#
# ********FINAL ITERATIVE TEMPLATE DEFORMATION********
# Compute Local values csf/gray
# Fine Segmentation...41 iterations
#
#       mri_strip_skull: done peeling brain
#
# Brain Size = 1507321 voxels, voxel volume = 1.000 mm3
#            = 1507321 mmm3 = 1507.321 cm3
#
#
# ******************************
# Saving brainmask.auto.mgz
# done
# mri_watershed utimesec    21.826679
# mri_watershed stimesec    0.170208
# mri_watershed ru_maxrss   816056
# mri_watershed ru_ixrss    0
# mri_watershed ru_idrss    0
# mri_watershed ru_isrss    0
# mri_watershed ru_minflt   188780
# mri_watershed ru_majflt   18
# mri_watershed ru_nswap    0
# mri_watershed ru_inblock  10072
# mri_watershed ru_oublock  2288
# mri_watershed ru_msgsnd   0
# mri_watershed ru_msgrcv   0
# mri_watershed ru_nsignals 0
# mri_watershed ru_nvcsw    821
# mri_watershed ru_nivcsw   1150
# mri_watershed done
#
#  cp brainmask.auto.mgz brainmask.mgz
#
# #-------------------------------------
# #@# EM Registration Mon Jan 10 16:18:29 UTC 2022
# /data/fs/rechuv/mri
#
#  mri_em_register -uns 3 -mask brainmask.mgz nu.mgz /apps/tvb-hip/freesurfer/average/RB_all_2020-01-02.gca transforms/talairach.lta
#
# setting unknown_nbr_spacing = 3
# using MR volume brainmask.mgz to mask input volume...
#
# == Number of threads available to mri_em_register for OpenMP = 8 ==
# reading 1 input volumes...
# logging results to talairach.log
# reading '/apps/tvb-hip/freesurfer/average/RB_all_2020-01-02.gca'...
# GCAread took 0 minutes and 0 seconds.
# average std = 7.2   using min determinant for regularization = 5.2
# 0 singular and 884 ill-conditioned covariance matrices regularized
# reading 'nu.mgz'...
# MRImask(): AllowDiffGeom = 1
# MRImask(): AllowDiffGeom = 1
# MRImask(): AllowDiffGeom = 1
# MRImask(): AllowDiffGeom = 1
# MRImask(): AllowDiffGeom = 1
# freeing gibbs priors...done.
# accounting for voxel sizes in initial transform
# bounding unknown intensity as < 5.9 or > 519.0
# total sample mean = 79.1 (1017 zeros)
# ************************************************
# spacing=8, using 2841 sample points, tol=1.00e-05...
# ************************************************
# register_mri: find_optimal_transform
# find_optimal_transform: nsamples 2841, passno 0, spacing 8
# resetting wm mean[0]: 98 --> 107
# resetting gm mean[0]: 61 --> 61
# input volume #1 is the most T1-like
# using real data threshold=25.0
# skull bounding box = (62, 53, 39) --> (192, 167, 191)
# finding center of left hemi white matter
# using (105, 91, 115) as brain centroid of Right_Cerebral_White_Matter...
# MRImask(): AllowDiffGeom = 1
# mean wm in atlas = 107, using box (89,77,96) --> (120, 104,133) to find MRI wm
# before smoothing, mri peak at 107
# robust fit to distribution - 107 +- 4.3
# after smoothing, mri peak at 107, scaling input intensities by 1.000
# scaling channel 0 by 1
# initial log_p = -3.956
# ************************************************
# First Search limited to translation only.
# ************************************************
# max log p =    -3.956314 @ (0.000, 0.000, 0.000)
# max log p =    -3.793835 @ (-5.263, 5.263, -5.263)
# max log p =    -3.746321 @ (2.632, 2.632, 2.632)
# max log p =    -3.731244 @ (1.316, 1.316, -1.316)
# max log p =    -3.707566 @ (0.658, 0.658, 3.289)
# max log p =    -3.707566 @ (0.000, 0.000, 0.000)
# max log p =    -3.707566 @ (0.000, 0.000, 0.000)
# max log p =    -3.707566 @ (0.000, 0.000, 0.000)
# Found translation: (-0.7, 9.9, -0.7): log p = -3.708
# ****************************************
# Nine parameter search.  iteration 0 nscales = 0 ...
# ****************************************
# Result so far: scale 1.000: max_log_p=-3.466, old_max_log_p =-3.708 (thresh=-3.7)
#  1.06375   0.00000   0.00000  -8.78348;
#  0.00000   1.15000   0.00000  -6.54486;
#  0.00000   0.00000   1.07500  -16.11381;
#  0.00000   0.00000   0.00000   1.00000;
# iteration took 0 minutes and 10 seconds.
# ****************************************
# Nine parameter search.  iteration 1 nscales = 0 ...
# ****************************************
# Result so far: scale 1.000: max_log_p=-3.466, old_max_log_p =-3.466 (thresh=-3.5)
#  1.06375   0.00000   0.00000  -8.78348;
#  0.00000   1.15000   0.00000  -6.54486;
#  0.00000   0.00000   1.07500  -16.11381;
#  0.00000   0.00000   0.00000   1.00000;
# reducing scale to 0.2500
# iteration took 0 minutes and 11 seconds.
# ****************************************
# Nine parameter search.  iteration 2 nscales = 1 ...
# ****************************************
# Result so far: scale 0.250: max_log_p=-3.319, old_max_log_p =-3.466 (thresh=-3.5)
#  1.06091  -0.07256  -0.03954   2.23680;
#  0.06942   1.14540   0.06557  -22.30352;
#  0.03553  -0.07408   1.09237  -10.68285;
#  0.00000   0.00000   0.00000   1.00000;
# iteration took 0 minutes and 11 seconds.
# ****************************************
# Nine parameter search.  iteration 3 nscales = 1 ...
# ****************************************
# Result so far: scale 0.250: max_log_p=-3.319, old_max_log_p =-3.319 (thresh=-3.3)
#  1.06091  -0.07256  -0.03954   2.23680;
#  0.06942   1.14540   0.06557  -22.30352;
#  0.03553  -0.07408   1.09237  -10.68285;
#  0.00000   0.00000   0.00000   1.00000;
# reducing scale to 0.0625
# iteration took 0 minutes and 11 seconds.
# ****************************************
# Nine parameter search.  iteration 4 nscales = 2 ...
# ****************************************
# Result so far: scale 0.062: max_log_p=-3.266, old_max_log_p =-3.319 (thresh=-3.3)
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03583   1.14553   0.10205  -21.97929;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
# iteration took 0 minutes and 10 seconds.
# ****************************************
# Nine parameter search.  iteration 5 nscales = 2 ...
# ****************************************
# Result so far: scale 0.062: max_log_p=-3.265, old_max_log_p =-3.266 (thresh=-3.3)
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
# min search scale 0.025000 reached
# ***********************************************
# Computing MAP estimate using 2841 samples...
# ***********************************************
# dt = 5.00e-06, momentum=0.80, tol=1.00e-05
# l_intensity = 1.0000
# Aligning input volume to GCA...
# Transform matrix
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
# nsamples 2841
# Quasinewton: input matrix
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
#  IFLAG= -1  LINE SEARCH FAILED. SEE DOCUMENTATION OF ROUTINE MCSRCH ERROR RETURN OF LINE SEARCH: INFO= 3 POSSIBLE CAUSES: FUNCTION OR GRADIENT ARE INCORRECT OR INCORRECT TOLERANCESoutof QuasiNewtonEMA: 008: -log(p) =   -0.0  tol 0.000010
# Resulting transform:
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
#
# pass 1, spacing 8: log(p) = -3.265 (old=-3.956)
# transform before final EM align:
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
#
# **************************************************
#  EM alignment process ...
#  Computing final MAP estimate using 315638 samples.
# **************************************************
# dt = 5.00e-06, momentum=0.80, tol=1.00e-07
# l_intensity = 1.0000
# Aligning input volume to GCA...
# Transform matrix
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
# nsamples 315638
# Quasinewton: input matrix
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
#  IFLAG= -1  LINE SEARCH FAILED. SEE DOCUMENTATION OF ROUTINE MCSRCH ERROR RETURN OF LINE SEARCH: INFO= 6 POSSIBLE CAUSES: FUNCTION OR GRADIENT ARE INCORRECT OR INCORRECT TOLERANCESoutof QuasiNewtonEMA: 010: -log(p) =    3.9  tol 0.000000
# final transform:
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
#
# writing output transformation to transforms/talairach.lta...
# #VMPC# mri_em_register VmPeak  824768
# FSRUNTIME@ mri_em_register  0.0341 hours 8 threads
# registration took 2 minutes and 3 seconds.
# #--------------------------------------
# #@# CA Normalize Mon Jan 10 16:20:32 UTC 2022
# /data/fs/rechuv/mri
#
#  mri_ca_normalize -c ctrl_pts.mgz -mask brainmask.mgz nu.mgz /apps/tvb-hip/freesurfer/average/RB_all_2020-01-02.gca transforms/talairach.lta norm.mgz
#
# writing control point volume to ctrl_pts.mgz
# using MR volume brainmask.mgz to mask input volume...
# reading 1 input volume
# reading atlas from '/apps/tvb-hip/freesurfer/average/RB_all_2020-01-02.gca'...
# reading transform from 'transforms/talairach.lta'...
# reading input volume from nu.mgz...
# resetting wm mean[0]: 98 --> 107
# resetting gm mean[0]: 61 --> 61
# input volume #1 is the most T1-like
# using real data threshold=25.0
# skull bounding box = (61, 53, 39) --> (192, 167, 191)
# finding center of left hemi white matter
# using (105, 91, 115) as brain centroid of Right_Cerebral_White_Matter...
# mean wm in atlas = 107, using box (89,77,96) --> (121, 104,133) to find MRI wm
# before smoothing, mri peak at 107
# robust fit to distribution - 107 +- 4.3
# after smoothing, mri peak at 107, scaling input intensities by 1.000
# scaling channel 0 by 1
# using 246437 sample points...
# INFO: compute sample coordinates transform
#  1.06413  -0.03610  -0.02731  -2.56753;
#  0.03591   1.14821   0.10229  -22.31039;
#  0.02457  -0.11049   1.08868  -6.27396;
#  0.00000   0.00000   0.00000   1.00000;
# INFO: transform used
# finding control points in Left_Cerebral_White_Matter....
# found 40230 control points for structure...
# bounding box (126, 51, 39) --> (190, 151, 192)
# Left_Cerebral_White_Matter: limiting intensities to 92.0 --> 132.0
# 0 of 4088 (0.0%) samples deleted
# finding control points in Right_Cerebral_White_Matter....
# found 39478 control points for structure...
# bounding box (66, 52, 39) --> (130, 155, 193)
# Right_Cerebral_White_Matter: limiting intensities to 96.0 --> 132.0
# 7 of 4424 (0.2%) samples deleted
# finding control points in Left_Cerebellum_White_Matter....
# found 3105 control points for structure...
# bounding box (129, 124, 62) --> (175, 164, 111)
# Left_Cerebellum_White_Matter: limiting intensities to 101.0 --> 132.0
# 0 of 91 (0.0%) samples deleted
# finding control points in Right_Cerebellum_White_Matter....
# found 2710 control points for structure...
# bounding box (87, 125, 60) --> (128, 165, 113)
# Right_Cerebellum_White_Matter: limiting intensities to 96.0 --> 132.0
# 0 of 68 (0.0%) samples deleted
# finding control points in Brain_Stem....
# found 3475 control points for structure...
# bounding box (113, 119, 95) --> (146, 179, 123)
# Brain_Stem: limiting intensities to 96.0 --> 132.0
# 0 of 289 (0.0%) samples deleted
# using 8960 total control points for intensity normalization...
# bias field = 0.972 +- 0.063
# 117 of 8953 control points discarded
# finding control points in Left_Cerebral_White_Matter....
# found 40230 control points for structure...
# bounding box (126, 51, 39) --> (190, 151, 192)
# Left_Cerebral_White_Matter: limiting intensities to 88.0 --> 132.0
# 23 of 4553 (0.5%) samples deleted
# finding control points in Right_Cerebral_White_Matter....
# found 39478 control points for structure...
# bounding box (66, 52, 39) --> (130, 155, 193)
# Right_Cerebral_White_Matter: limiting intensities to 91.0 --> 132.0
# 11 of 4885 (0.2%) samples deleted
# finding control points in Left_Cerebellum_White_Matter....
# found 3105 control points for structure...
# bounding box (129, 124, 62) --> (175, 164, 111)
# Left_Cerebellum_White_Matter: limiting intensities to 88.0 --> 132.0
# 2 of 181 (1.1%) samples deleted
# finding control points in Right_Cerebellum_White_Matter....
# found 2710 control points for structure...
# bounding box (87, 125, 60) --> (128, 165, 113)
# Right_Cerebellum_White_Matter: limiting intensities to 88.0 --> 132.0
# 12 of 121 (9.9%) samples deleted
# finding control points in Brain_Stem....
# found 3475 control points for structure...
# bounding box (113, 119, 95) --> (146, 179, 123)
# Brain_Stem: limiting intensities to 88.0 --> 132.0
# 26 of 409 (6.4%) samples deleted
# using 10149 total control points for intensity normalization...
# bias field = 1.020 +- 0.056
# 69 of 10003 control points discarded
# finding control points in Left_Cerebral_White_Matter....
# found 40230 control points for structure...
# bounding box (126, 51, 39) --> (190, 151, 192)
# Left_Cerebral_White_Matter: limiting intensities to 88.0 --> 132.0
# 22 of 4515 (0.5%) samples deleted
# finding control points in Right_Cerebral_White_Matter....
# found 39478 control points for structure...
# bounding box (66, 52, 39) --> (130, 155, 193)
# Right_Cerebral_White_Matter: limiting intensities to 90.0 --> 132.0
# 12 of 4899 (0.2%) samples deleted
# finding control points in Left_Cerebellum_White_Matter....
# found 3105 control points for structure...
# bounding box (129, 124, 62) --> (175, 164, 111)
# Left_Cerebellum_White_Matter: limiting intensities to 88.0 --> 132.0
# 11 of 213 (5.2%) samples deleted
# finding control points in Right_Cerebellum_White_Matter....
# found 2710 control points for structure...
# bounding box (87, 125, 60) --> (128, 165, 113)
# Right_Cerebellum_White_Matter: limiting intensities to 88.0 --> 132.0
# 36 of 179 (20.1%) samples deleted
# finding control points in Brain_Stem....
# found 3475 control points for structure...
# bounding box (113, 119, 95) --> (146, 179, 123)
# Brain_Stem: limiting intensities to 88.0 --> 132.0
# 79 of 430 (18.4%) samples deleted
# using 10236 total control points for intensity normalization...
# bias field = 1.015 +- 0.050
# 63 of 9924 control points discarded
# writing normalized volume to norm.mgz...
# writing control points to ctrl_pts.mgz
# freeing GCA...done.
# normalization took 0 minutes and 59 seconds.
# #--------------------------------------
# #@# CA Reg Mon Jan 10 16:21:31 UTC 2022
# /data/fs/rechuv/mri
#
#  mri_ca_register -nobigventricles -T transforms/talairach.lta -align-after -mask brainmask.mgz norm.mgz /apps/tvb-hip/freesurfer/average/RB_all_2020-01-02.gca transforms/talairach.m3z
#
# not handling expanded ventricles...
# using previously computed transform transforms/talairach.lta
# renormalizing sequences with structure alignment, equivalent to:
# 	-renormalize
# 	-regularize_mean 0.500
# 	-regularize 0.500
# using MR volume brainmask.mgz to mask input volume...
#
# == Number of threads available to mri_ca_register for OpenMP = 8 ==
# reading 1 input volumes...
# logging results to talairach.log
# reading input volume 'norm.mgz'...
# reading GCA '/apps/tvb-hip/freesurfer/average/RB_all_2020-01-02.gca'...
# label assignment complete, 0 changed (0.00%)
# freeing gibbs priors...done.
# average std[0] = 5.0
# Starting GCAMregister()
# label assignment complete, 0 changed (0.00%)
# npasses = 1, nlevels = 6
# #pass# 1 of 1 ************************
# enabling zero nodes
# setting smoothness cost coefficient to 0.156
#
# #GCAMreg# pass 0 level1 5 level2 0 tsec 0 sigma 2
# l_jacobian=1.00 l_label=1.00 l_log_likelihood=0.20 l_smoothness=0.16
# tol=2.50e-01, dt=5.00e-02, exp_k=20.0, momentum=0.90, levels=6, niter=500, lbl_dist=10.00, avgs=256, sigma=2.0,type=2, relabel=0, neg=no
#
# blurring input image with Gaussian with sigma=2.000...
# GCAMRegisterLevel(): init RMS 0.832886
# #FOTS# QuadFit found better minimum quadopt=(dt=221.952,rms=0.744427) vs oldopt=(dt=369.92,rms=0.775333)
# #GCMRL#    0 dt 221.952000 rms  0.744 10.621% neg 0  invalid 762 tFOTS 6.6410 tGradient 2.2700 tsec 9.4040
# #FOTS# QuadFit found better minimum quadopt=(dt=168.186,rms=0.730167) vs oldopt=(dt=92.48,rms=0.733361)
# #GCMRL#    1 dt 168.186047 rms  0.730  1.915% neg 0  invalid 762 tFOTS 6.5610 tGradient 2.2210 tsec 9.3130
# #FOTS# QuadFit found better minimum quadopt=(dt=197.284,rms=0.721064) vs oldopt=(dt=92.48,rms=0.724192)
# #GCMRL#    2 dt 197.284404 rms  0.721  1.247% neg 0  invalid 762 tFOTS 7.1230 tGradient 2.4230 tsec 10.0850
# #FOTS# QuadFit found better minimum quadopt=(dt=149.98,rms=0.716388) vs oldopt=(dt=92.48,rms=0.717377)
# #GCMRL#    3 dt 149.979798 rms  0.716  0.649% neg 0  invalid 762 tFOTS 7.1180 tGradient 2.2950 tsec 10.0040
# #FOTS# QuadFit found better minimum quadopt=(dt=295.936,rms=0.711478) vs oldopt=(dt=369.92,rms=0.711578)
# #GCMRL#    4 dt 295.936000 rms  0.711  0.685% neg 0  invalid 762 tFOTS 7.1330 tGradient 2.1030 tsec 9.8150
# #FOTS# QuadFit found better minimum quadopt=(dt=129.472,rms=0.708515) vs oldopt=(dt=92.48,rms=0.708752)
# #GCMRL#    5 dt 129.472000 rms  0.709  0.416% neg 0  invalid 762 tFOTS 6.4760 tGradient 1.9980 tsec 9.0360
# #GCMRL#    6 dt 369.920000 rms  0.705  0.443% neg 0  invalid 762 tFOTS 6.7340 tGradient 2.0410 tsec 9.2360
# #FOTS# QuadFit found better minimum quadopt=(dt=110.976,rms=0.703107) vs oldopt=(dt=92.48,rms=0.703142)
# #GCMRL#    7 dt 110.976000 rms  0.703  0.322% neg 0  invalid 762 tFOTS 6.8050 tGradient 1.8980 tsec 9.1850
# #FOTS# QuadFit found better minimum quadopt=(dt=517.888,rms=0.700221) vs oldopt=(dt=369.92,rms=0.7006)
# #GCMRL#    8 dt 517.888000 rms  0.700  0.410% neg 0  invalid 762 tFOTS 7.2670 tGradient 2.2400 tsec 9.9970
# #GCMRL#    9 dt  92.480000 rms  0.699  0.000% neg 0  invalid 762 tFOTS 7.3020 tGradient 2.0960 tsec 9.9510
# #GCMRL#   10 dt  92.480000 rms  0.698  0.067% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1310 tsec 2.7010
# #GCMRL#   11 dt  92.480000 rms  0.697  0.125% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1750 tsec 2.6970
# #GCMRL#   12 dt  92.480000 rms  0.696  0.167% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.3470 tsec 2.8630
# #GCMRL#   13 dt  92.480000 rms  0.695  0.186% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.2080 tsec 2.6760
# #GCMRL#   14 dt  92.480000 rms  0.694  0.206% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.0810 tsec 2.5800
# #GCMRL#   15 dt  92.480000 rms  0.692  0.206% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.4070 tsec 2.8910
# #GCMRL#   16 dt  92.480000 rms  0.691  0.211% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1490 tsec 2.6720
# #GCMRL#   17 dt  92.480000 rms  0.689  0.197% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.3250 tsec 2.8760
# #GCMRL#   18 dt  92.480000 rms  0.688  0.197% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1870 tsec 2.7290
# #GCMRL#   19 dt  92.480000 rms  0.687  0.197% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1830 tsec 2.7030
# #GCMRL#   20 dt  92.480000 rms  0.685  0.175% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.2330 tsec 2.7550
# #GCMRL#   21 dt  92.480000 rms  0.684  0.161% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.2630 tsec 2.8090
# #GCMRL#   22 dt  92.480000 rms  0.683  0.182% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.3650 tsec 2.8760
# #GCMRL#   23 dt  92.480000 rms  0.682  0.167% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.3330 tsec 2.8670
# #GCMRL#   24 dt  92.480000 rms  0.681  0.149% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.3270 tsec 2.8620
# #GCMRL#   25 dt  92.480000 rms  0.680  0.145% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.2670 tsec 2.7820
# #GCMRL#   26 dt  92.480000 rms  0.679  0.132% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.3240 tsec 2.8150
# #GCMRL#   27 dt  92.480000 rms  0.678  0.125% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1480 tsec 2.7060
# #GCMRL#   28 dt  92.480000 rms  0.677  0.116% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1570 tsec 2.6660
# #FOTS# QuadFit found better minimum quadopt=(dt=887.808,rms=0.677008) vs oldopt=(dt=1479.68,rms=0.677105)
# #GCMRL#   29 dt 887.808000 rms  0.677  0.000% neg 0  invalid 762 tFOTS 7.2880 tGradient 2.0890 tsec 9.9320
#
# #GCAMreg# pass 0 level1 5 level2 1 tsec 164.182 sigma 0.5
# l_jacobian=1.00 l_label=1.00 l_log_likelihood=0.20 l_smoothness=0.16
# tol=2.50e-01, dt=5.00e-02, exp_k=20.0, momentum=0.90, levels=6, niter=500, lbl_dist=10.00, avgs=256, sigma=0.5,type=2, relabel=0, neg=no
#
# blurring input image with Gaussian with sigma=0.500...
# GCAMRegisterLevel(): init RMS 0.677788
# #FOTS# QuadFit found better minimum quadopt=(dt=129.472,rms=0.676045) vs oldopt=(dt=92.48,rms=0.676229)
# #GCMRL#   31 dt 129.472000 rms  0.676  0.257% neg 0  invalid 762 tFOTS 6.8650 tGradient 2.3010 tsec 9.7000
# #FOTS# QuadFit found better minimum quadopt=(dt=517.888,rms=0.675153) vs oldopt=(dt=369.92,rms=0.675264)
# #GCMRL#   32 dt 517.888000 rms  0.675  0.000% neg 0  invalid 762 tFOTS 6.7000 tGradient 2.2620 tsec 9.5250
# #GCMRL#   33 dt 517.888000 rms  0.675  0.053% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.3470 tsec 2.8510
# #GCMRL#   34 dt 517.888000 rms  0.675  0.021% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.2150 tsec 2.6940
# setting smoothness cost coefficient to 0.615
#
# #GCAMreg# pass 0 level1 4 level2 0 tsec 0 sigma 2
# l_jacobian=1.00 l_label=1.00 l_log_likelihood=0.20 l_smoothness=0.62
# tol=2.50e-01, dt=5.00e-02, exp_k=20.0, momentum=0.90, levels=6, niter=500, lbl_dist=10.00, avgs=64, sigma=2.0,type=2, relabel=0, neg=no
#
# blurring input image with Gaussian with sigma=2.000...
# GCAMRegisterLevel(): init RMS 0.687059
# #FOTS# QuadFit found better minimum quadopt=(dt=36.288,rms=0.684458) vs oldopt=(dt=25.92,rms=0.684785)
# #GCMRL#   36 dt  36.288000 rms  0.684  0.379% neg 0  invalid 762 tFOTS 6.8320 tGradient 1.9860 tsec 9.3160
# #FOTS# QuadFit found better minimum quadopt=(dt=63.1233,rms=0.683381) vs oldopt=(dt=103.68,rms=0.683707)
# #GCMRL#   37 dt  63.123288 rms  0.683  0.000% neg 0  invalid 762 tFOTS 6.6330 tGradient 2.0630 tsec 9.2440
# #GCMRL#   38 dt  63.123288 rms  0.682  0.247% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1300 tsec 2.6800
# #GCMRL#   39 dt  63.123288 rms  0.679  0.326% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.7210 tsec 3.3290
# #GCMRL#   40 dt  63.123288 rms  0.677  0.334% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.4240 tsec 3.0340
# #GCMRL#   41 dt  63.123288 rms  0.675  0.385% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.4550 tsec 3.0620
# #GCMRL#   42 dt  63.123288 rms  0.671  0.521% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.9310 tsec 3.5560
# #GCMRL#   43 dt  63.123288 rms  0.667  0.579% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.1720 tsec 2.7450
# #GCMRL#   44 dt  63.123288 rms  0.664  0.543% neg 0  invalid 762 tFOTS 0.0000 tGradient 3.2860 tsec 3.9730
# #GCMRL#   45 dt  63.123288 rms  0.661  0.457% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.8450 tsec 3.6280
# #GCMRL#   46 dt  63.123288 rms  0.659  0.302% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.9530 tsec 3.8090
# #GCMRL#   47 dt  63.123288 rms  0.657  0.175% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.8730 tsec 3.6590
# #GCMRL#   48 dt  63.123288 rms  0.657  0.060% neg 0  invalid 762 tFOTS 0.0000 tGradient 2.9340 tsec 3.5990
# #GCMRL#   49 dt  63.123288 rms  0.657  0.009% neg 0  invalid 762 tFOTS 0.0000 tGradient 3.0200 tsec 3.8420
# #FOTS# QuadFit found better minimum quadopt=(dt=145.152,rms=0.656602) vs oldopt=(dt=103.68,rms=0.656624)
# #GCMRL#   50 dt 145.152000 rms  0.657  0.050% neg 0  invalid 762 tFOTS 8.9000 tGradient 2.9050 tsec 12.5080
# #FOTS# QuadFit found better minimum quadopt=(dt=124.416,rms=0.656353) vs oldopt=(dt=103.68,rms=0.656353)
# #GCMRL#   51 dt 124.416000 rms  0.656  0.000% neg 0  invalid 762 tFOTS 8.9360 tGradient 2.8010 tsec 12.5630
#
# #GCAMreg# pass 0 level1 4 level2 1 tsec 91.237 sigma 0.5
# l_jacobian=1.00 l_label=1.00 l_log_likelihood=0.20 l_smoothness=0.62
# tol=2.50e-01, dt=5.00e-02, exp_k=20.0, momentum=0.90, levels=6, niter=500, lbl_dist=10.00, avgs=64, sigma=0.5,type=2, relabel=0, neg=no
#
# blurring input image with Gaussian with sigma=0.500...
# GCAMRegisterLevel(): init RMS 0.657032
# #GCMRL#   53 dt  25.920000 rms  0.656  0.118% neg 0  invalid 762 tFOTS 9.2390 tGradient 2.8300 tsec 12.7990
# #FOTS# QuadFit found better minimum quadopt=(dt=0.567,rms=0.656241) vs oldopt=(dt=0.405,rms=0.656241)
# #GCMRL#   54 dt   0.567000 rms  0.656  0.000% neg 0  invalid 762 tFOTS 9.2190 tGradient 2.5660 tsec 12.4580
# setting smoothness cost coefficient to 2.353
#
# #GCAMreg# pass 0 level1 3 level2 0 tsec 0 sigma 2
# l_jacobian=1.00 l_label=1.00 l_log_likelihood=0.20 l_smoothness=2.35
# tol=2.50e-01, dt=5.00e-02, exp_k=20.0, momentum=0.90, levels=6, niter=500, lbl_dist=10.00, avgs=16, sigma=2.0,type=2, relabel=0, neg=no
#
# blurring input image with Gaussian with sigma=2.000...
# GCAMRegisterLevel(): init RMS 0.686636
# #FOTS# QuadFit found better minimum quadopt=(dt=0.7,rms=0.685939) vs oldopt=(dt=0.5,rms=0.685948)
# #GCMRL#   56 dt   0.700000 rms  0.686  0.102% neg 0  invalid 762 tFOTS 6.7620 tGradient 1.9890 tsec 9.3480
# #FOTS# QuadFit found better minimum quadopt=(dt=0.175,rms=0.685947) vs oldopt=(dt=0.125,rms=0.685947)
#
# #GCAMreg# pass 0 level1 3 level2 1 tsec 21.517 sigma 0.5
# l_jacobian=1.00 l_label=1.00 l_log_likelihood=0.20 l_smoothness=2.35
# tol=2.50e-01, dt=5.00e-02, exp_k=20.0, momentum=0.90, levels=6, niter=500, lbl_dist=10.00, avgs=16, sigma=0.5,type=2, relabel=0, neg=no
#
# blurring input image with Gaussian with sigma=0.500...
# GCAMRegisterLevel(): init RMS 0.68658
# #FOTS# QuadFit found better minimum quadopt=(dt=0.7,rms=0.685896) vs oldopt=(dt=0.5,rms=0.685904)
# ...
#
# Reading ctab /apps/tvb-hip/freesurfer/average/colortable_BA.txt
# Number of ctab entries 15
#
# 7.2.0
# cwd /data/fs/rechuv/label
# cmdline mris_label2annot --s rechuv --hemi rh --ctab /apps/tvb-hip/freesurfer/average/colortable_BA.txt --l rh.BA1_exvivo.thresh.label --l rh.BA2_exvivo.thresh.label --l rh.BA3a_exvivo.thresh.label --l rh.BA3b_exvivo.thresh.label --l rh.BA4a_exvivo.thresh.label --l rh.BA4p_exvivo.thresh.label --l rh.BA6_exvivo.thresh.label --l rh.BA44_exvivo.thresh.label --l rh.BA45_exvivo.thresh.label --l rh.V1_exvivo.thresh.label --l rh.V2_exvivo.thresh.label --l rh.MT_exvivo.thresh.label --l rh.perirhinal_exvivo.thresh.label --l rh.entorhinal_exvivo.thresh.label --a BA_exvivo.thresh --maxstatwinner --noverbose
# sysname  Linux
# hostname ad03c415e0ad
# machine  x86_64
# user     root
#
# subject rechuv
# hemi    rh
# SUBJECTS_DIR /data/fs
# ColorTable /apps/tvb-hip/freesurfer/average/colortable_BA.txt
# AnnotName  BA_exvivo.thresh
# nlables 14
# LabelThresh 0 0.000000
# Loading /data/fs/rechuv/surf/rh.orig
#  1 1530880 BA1_exvivo
#  2 16749699 BA2_exvivo
#  3 16711680 BA3a_exvivo
#  4 3368703 BA3b_exvivo
#  5 1376196 BA4a_exvivo
#  6 13382655 BA4p_exvivo
#  7 10036737 BA6_exvivo
#  8 2490521 BA44_exvivo
#  9 39283 BA45_exvivo
# 10 3993 V1_exvivo
# 11 8508928 V2_exvivo
# 12 10027163 MT_exvivo
# 13 16422433 perirhinal_exvivo
# 14 16392598 entorhinal_exvivo
# Mapping unhit to unknown
# Found 103866 unhit vertices
# Writing annot to /data/fs/rechuv/label/rh.BA_exvivo.thresh.annot
#
#  mris_anatomical_stats -th3 -mgz -f ../stats/rh.BA_exvivo.stats -b -a ./rh.BA_exvivo.annot -c ./BA_exvivo.ctab rechuv rh white
#
# computing statistics for each annotation in ./rh.BA_exvivo.annot.
# reading volume /data/fs/rechuv/mri/wm.mgz...
# reading input surface /data/fs/rechuv/surf/rh.white...
# reading input pial surface /data/fs/rechuv/surf/rh.pial...
# reading input white surface /data/fs/rechuv/surf/rh.white...
# INFO: using TH3 volume calc
# INFO: assuming MGZ format for volumes.
# Using TH3 vertex volume calc
# Total face volume 197714
# Total vertex volume 197527 (mask=0)
# Saving annotation colortable ./BA_exvivo.ctab
#
# table columns are:
#     number of vertices
#     total surface area (mm^2)
#     total gray matter volume (mm^3)
#     average cortical thickness +- standard deviation (mm)
#     integrated rectified mean curvature
#     integrated rectified Gaussian curvature
#     folding index
#     intrinsic curvature index
#     structure name
#
# atlas_icv (eTIV) = 1243097 mm^3    (det: 1.567139 )
#   535    367    998  2.257 0.451     0.148     0.033        8     0.7  BA1_exvivo
#  1710   1171   2817  2.139 0.668     0.109     0.022       13     1.6  BA2_exvivo
#   809    537    791  1.947 0.396     0.131     0.027        6     1.0  BA3a_exvivo
#  1247    825   1888  2.157 0.475     0.092     0.018        7     0.9  BA3b_exvivo
#  1184    726   1501  1.934 0.408     0.088     0.016        6     0.7  BA4a_exvivo
#   972    624   1131  1.799 0.401     0.088     0.017        5     0.7  BA4p_exvivo
#  7188   4435  10663  2.151 0.590     0.108     0.026       60     7.8  BA6_exvivo
#  4390   2902   7859  2.501 0.482     0.111     0.024       36     4.1  BA44_exvivo
#  3936   2672   7728  2.541 0.538     0.124     0.027       41     4.3  BA45_exvivo
#  4197   2737   4414  1.558 0.469     0.129     0.032       44     5.6  V1_exvivo
#  8898   5759  10846  1.789 0.532     0.130     0.031       96    11.2  V2_exvivo
#  2178   1494   3648  2.195 0.582     0.127     0.027       21     2.6  MT_exvivo
#   339    222    664  2.618 0.575     0.079     0.011        1     0.2  perirhinal_exvivo
#   554    345   1928  3.243 0.833     0.094     0.017        3     0.4  entorhinal_exvivo
#
#  mris_anatomical_stats -th3 -mgz -f ../stats/rh.BA_exvivo.thresh.stats -b -a ./rh.BA_exvivo.thresh.annot -c ./BA_exvivo.thresh.ctab rechuv rh white
#
# computing statistics for each annotation in ./rh.BA_exvivo.thresh.annot.
# reading volume /data/fs/rechuv/mri/wm.mgz...
# reading input surface /data/fs/rechuv/surf/rh.white...
# reading input pial surface /data/fs/rechuv/surf/rh.pial...
# reading input white surface /data/fs/rechuv/surf/rh.white...
# INFO: using TH3 volume calc
# INFO: assuming MGZ format for volumes.
# Using TH3 vertex volume calc
# Total face volume 197714
# Total vertex volume 197527 (mask=0)
# Saving annotation colortable ./BA_exvivo.thresh.ctab
#
# table columns are:
#     number of vertices
#     total surface area (mm^2)
#     total gray matter volume (mm^3)
#     average cortical thickness +- standard deviation (mm)
#     integrated rectified mean curvature
#     integrated rectified Gaussian curvature
#     folding index
#     intrinsic curvature index
#     structure name
#
# atlas_icv (eTIV) = 1243097 mm^3    (det: 1.567139 )
#   303    209    529  2.269 0.471     0.118     0.023        3     0.3  BA1_exvivo
#   972    661   1718  2.188 0.590     0.105     0.024        9     0.9  BA2_exvivo
#   705    464    621  1.913 0.389     0.133     0.029        5     0.9  BA3a_exvivo
#   994    650   1325  2.061 0.447     0.074     0.012        3     0.5  BA3b_exvivo
#   718    411    915  2.012 0.437     0.096     0.020        5     0.5  BA4a_exvivo
#   804    515    845  1.713 0.327     0.081     0.015        3     0.5  BA4p_exvivo
#  4356   2643   6023  2.060 0.540     0.108     0.027       38     5.0  BA6_exvivo
#   870    567   1702  2.581 0.485     0.105     0.021        8     0.7  BA44_exvivo
#   956    657   2119  2.693 0.391     0.146     0.033       13     1.3  BA45_exvivo
#  3990   2616   4095  1.534 0.460     0.128     0.031       40     5.2  V1_exvivo
#  4674   3030   5581  1.747 0.515     0.138     0.033       57     6.4  V2_exvivo
#   299    212    523  2.114 0.562     0.147     0.036        4     0.5  MT_exvivo
#    26     16     46  2.706 0.197     0.068     0.009        0     0.0  perirhinal_exvivo
#   543    343   1646  3.101 0.826     0.081     0.015        2     0.4  entorhinal_exvivo
#
# Started at Mon Jan 10 16:07:49 UTC 2022
# Ended   at Mon Jan 10 22:35:48 UTC 2022
# #@#%# recon-all-run-time-hours 6.466
# recon-all -s rechuv finished without error at Mon Jan 10 22:35:48 UTC 2022
# done
# mri_surf2surf \
# 	--srcsubject rechuv \
# 	--trgsubject fsaverage5 \
# 	--hemi lh \
# 	--sval-xyz pial \
# 	--tval pial.rechuv \
# 	--tval-xyz /data/fs/rechuv/mri/T1.mgz
#
# 7.2.0
#
# setenv SUBJECTS_DIR /data/fs
# cd /work/tvb-pipeline
# mri_surf2surf --srcsubject rechuv --trgsubject fsaverage5 --hemi lh --sval-xyz pial --tval pial.rechuv --tval-xyz /data/fs/rechuv/mri/T1.mgz
#
# sysname  Linux
# hostname ad03c415e0ad
# machine  x86_64
# user     root
# srcsubject = rechuv
# srcval     = (null)
# srctype    =
# trgsubject = fsaverage5
# trgval     = pial.rechuv
# trgtype    =
# srcsurfreg = sphere.reg
# trgsurfreg = sphere.reg
# srchemi    = lh
# trghemi    = lh
# frame      = 0
# fwhm-in    = 0
# fwhm-out   = 0
# label-src  = (null)
# label-trg  = (null)
# OKToRevFaceOrder  = 1
# UseDualHemi = 0
# Reading source surface reg /data/fs/rechuv/surf/lh.sphere.reg
# Loading source data
# Reading surface file /data/fs/rechuv/surf/lh.pial
# Reading target surface reg /data/fs/fsaverage5/surf/lh.sphere.reg
# Done
# Using surf2surf_nnfr()
# Mapping Source Volume onto Source Subject Surface
# surf2surf_nnfr: building source hash (res=16).
# Surf2Surf: Forward Loop (10242)
#
# surf2surf_nnfr: building target hash (res=16).
# Surf2Surf: Reverse Loop (120236)
# Reverse Loop had 109994 hits
# Surf2Surf: Dividing by number of hits (10242)
# INFO: nSrcLost = 0
# nTrg121 =     0, nTrgMulti = 10242, MnTrgMultiHits = 11.7395
# nSrc121 = 120236, nSrcLost =     0, nSrcMulti =     0, MnSrcMultiHits = 0
# Saving target data
# cp /data/fs/fsaverage5/surf/lh.pial.rechuv \
#     /data/fs/rechuv/surf/lh.pial.fsaverage5
# mri_surf2surf \
# 	--srcsubject rechuv \
# 	--trgsubject fsaverage5 \
# 	--hemi lh \
# 	--sval-annot /data/fs/rechuv/label/lh.aparc.a2009s.annot \
# 	--tval /data/fs/rechuv/label/lh.aparc.a2009s.annot.fsaverage5
# Setting mapmethod to nnf
#
# 7.2.0
#
# setenv SUBJECTS_DIR /data/fs
# cd /work/tvb-pipeline
# mri_surf2surf --srcsubject rechuv --trgsubject fsaverage5 --hemi lh --sval-annot /data/fs/rechuv/label/lh.aparc.a2009s.annot --tval /data/fs/rechuv/label/lh.aparc.a2009s.annot.fsaverage5
#
# sysname  Linux
# hostname ad03c415e0ad
# machine  x86_64
# user     root
# srcsubject = rechuv
# srcval     = (null)
# srctype    =
# trgsubject = fsaverage5
# trgval     = /data/fs/rechuv/label/lh.aparc.a2009s.annot.fsaverage5
# trgtype    =
# srcsurfreg = sphere.reg
# trgsurfreg = sphere.reg
# srchemi    = lh
# trghemi    = lh
# frame      = 0
# fwhm-in    = 0
# fwhm-out   = 0
# label-src  = (null)
# label-trg  = (null)
# OKToRevFaceOrder  = 1
# UseDualHemi = 0
# Reading source surface reg /data/fs/rechuv/surf/lh.sphere.reg
# Loading source data
# Reading surface file /data/fs/rechuv/surf/lh.orig
# Reading target surface reg /data/fs/fsaverage5/surf/lh.sphere.reg
# Done
# Using surf2surf_nnfr()
# Mapping Source Volume onto Source Subject Surface
# surf2surf_nnfr: building source hash (res=16).
# Surf2Surf: Forward Loop (10242)
#
# Surf2Surf: Dividing by number of hits (10242)
# INFO: nSrcLost = 109994
# nTrg121 = 10242, nTrgMulti =     0, MnTrgMultiHits = 0
# nSrc121 = 10242, nSrcLost = 109994, nSrcMulti = 109994, MnSrcMultiHits = 0
# Saving target data
# Converting to target annot
# Saving to target annot /data/fs/rechuv/label/lh.aparc.a2009s.annot.fsaverage5
# mri_surf2surf \
# 	--srcsubject rechuv \
# 	--trgsubject fsaverage5 \
# 	--hemi rh \
# 	--sval-xyz pial \
# 	--tval pial.rechuv \
# 	--tval-xyz /data/fs/rechuv/mri/T1.mgz
#
# 7.2.0
#
# setenv SUBJECTS_DIR /data/fs
# cd /work/tvb-pipeline
# mri_surf2surf --srcsubject rechuv --trgsubject fsaverage5 --hemi rh --sval-xyz pial --tval pial.rechuv --tval-xyz /data/fs/rechuv/mri/T1.mgz
#
# sysname  Linux
# hostname ad03c415e0ad
# machine  x86_64
# user     root
# srcsubject = rechuv
# srcval     = (null)
# srctype    =
# trgsubject = fsaverage5
# trgval     = pial.rechuv
# trgtype    =
# srcsurfreg = sphere.reg
# trgsurfreg = sphere.reg
# srchemi    = rh
# trghemi    = rh
# frame      = 0
# fwhm-in    = 0
# fwhm-out   = 0
# label-src  = (null)
# label-trg  = (null)
# OKToRevFaceOrder  = 1
# UseDualHemi = 0
# Reading source surface reg /data/fs/rechuv/surf/rh.sphere.reg
# Loading source data
# Reading surface file /data/fs/rechuv/surf/rh.pial
# Reading target surface reg /data/fs/fsaverage5/surf/rh.sphere.reg
# Done
# Using surf2surf_nnfr()
# Mapping Source Volume onto Source Subject Surface
# surf2surf_nnfr: building source hash (res=16).
# Surf2Surf: Forward Loop (10242)
#
# surf2surf_nnfr: building target hash (res=16).
# Surf2Surf: Reverse Loop (124076)
# Reverse Loop had 113834 hits
# Surf2Surf: Dividing by number of hits (10242)
# INFO: nSrcLost = 0
# nTrg121 =     0, nTrgMulti = 10242, MnTrgMultiHits = 12.1144
# nSrc121 = 124076, nSrcLost =     0, nSrcMulti =     0, MnSrcMultiHits = 0
# Saving target data
# cp /data/fs/fsaverage5/surf/rh.pial.rechuv \
#     /data/fs/rechuv/surf/rh.pial.fsaverage5
# mri_surf2surf \
# 	--srcsubject rechuv \
# 	--trgsubject fsaverage5 \
# 	--hemi rh \
# 	--sval-annot /data/fs/rechuv/label/rh.aparc.a2009s.annot \
# 	--tval /data/fs/rechuv/label/rh.aparc.a2009s.annot.fsaverage5
# Setting mapmethod to nnf
#
# 7.2.0
#
# setenv SUBJECTS_DIR /data/fs
# cd /work/tvb-pipeline
# mri_surf2surf --srcsubject rechuv --trgsubject fsaverage5 --hemi rh --sval-annot /data/fs/rechuv/label/rh.aparc.a2009s.annot --tval /data/fs/rechuv/label/rh.aparc.a2009s.annot.fsaverage5
#
# sysname  Linux
# hostname ad03c415e0ad
# machine  x86_64
# user     root
# srcsubject = rechuv
# srcval     = (null)
# srctype    =
# trgsubject = fsaverage5
# trgval     = /data/fs/rechuv/label/rh.aparc.a2009s.annot.fsaverage5
# trgtype    =
# srcsurfreg = sphere.reg
# trgsurfreg = sphere.reg
# srchemi    = rh
# trghemi    = rh
# frame      = 0
# fwhm-in    = 0
# fwhm-out   = 0
# label-src  = (null)
# label-trg  = (null)
# OKToRevFaceOrder  = 1
# UseDualHemi = 0
# Reading source surface reg /data/fs/rechuv/surf/rh.sphere.reg
# Loading source data
# Reading surface file /data/fs/rechuv/surf/rh.orig
# Reading target surface reg /data/fs/fsaverage5/surf/rh.sphere.reg
# Done
# Using surf2surf_nnfr()
# Mapping Source Volume onto Source Subject Surface
# surf2surf_nnfr: building source hash (res=16).
# Surf2Surf: Forward Loop (10242)
#
# Surf2Surf: Dividing by number of hits (10242)
# INFO: nSrcLost = 113834
# nTrg121 = 10242, nTrgMulti =     0, MnTrgMultiHits = 0
# nSrc121 = 10242, nSrcLost = 113834, nSrcMulti = 113834, MnSrcMultiHits = 0
# Saving target data
# Converting to target annot
# Saving to target annot /data/fs/rechuv/label/rh.aparc.a2009s.annot.fsaverage5
# mkdir -p /data/fs/rechuv/dwi
# mrconvert  -force /data/chuv/mri/ep2d_diff_MGHDTI2_tra48x2_12 /data/fs/rechuv/dwi/raw.mif >> /data/fs/rechuv/dwi/log.txt 2>&1
# # dwipreproc -force -rpe_none AP /data/fs/rechuv/dwi/raw.mif /data/fs/rechuv/dwi/preproc.mif
# # TODO reconutil func to invoke dwipreproc correctly
# cp /data/fs/rechuv/dwi/raw.mif /data/fs/rechuv/dwi/preproc.mif >> /data/fs/rechuv/dwi/log.txt 2>&1
# dwi2response -nthreads 8 -force tournier /data/fs/rechuv/dwi/preproc.mif /data/fs/rechuv/dwi/response.txt >> /data/fs/rechuv/dwi/log.txt 2>&1
# dwi2fod csd /data/fs/rechuv/dwi/preproc.mif /data/fs/rechuv/dwi/response.txt /data/fs/rechuv/dwi/fod.mif -force -nthreads 8 >> /data/fs/rechuv/dwi/log.txt 2>&1
# dwi2mask -force /data/fs/rechuv/dwi/preproc.mif /data/fs/rechuv/dwi/mask.mif >> /data/fs/rechuv/dwi/log.txt 2>&1
# tckgen /data/fs/rechuv/dwi/fod.mif /data/fs/rechuv/dwi/all.tck \
#     -mask /data/fs/rechuv/dwi/mask.mif \
#     -seed_image /data/fs/rechuv/dwi/mask.mif \
#     -select 15M -force -nthreads 8 >> /data/fs/rechuv/dwi/log.txt 2>&1
# ln -sf ./aparc+aseg.mgz /data/fs/rechuv/mri/aparc+aseg.dk.mgz
# mri_convert -rt nearest --out_orientation RAS /data/fs/rechuv/mri/aparc+aseg.dk.mgz /data/fs/rechuv/mri/aparc+aseg.dk.RAS.nii.gz
# mri_convert -rt nearest --out_orientation RAS /data/fs/rechuv/mri/aparc+aseg.dk.mgz /data/fs/rechuv/mri/aparc+aseg.dk.RAS.nii.gz
# reading from /data/fs/rechuv/mri/aparc+aseg.dk.mgz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.00867e-11, -9.31323e-10)
# j_ras = (-9.31323e-10, 7.46431e-09, -1)
# k_ras = (-1.11429e-10, 1, -7.46587e-09)
# MRIcopyHeader(): source has ctab
# Setting output orientation to RAS
# Reslicing using nearest
# writing to /data/fs/rechuv/mri/aparc+aseg.dk.RAS.nii.gz...
# fslreorient2std /data/fs/rechuv/mri/aparc+aseg.dk.RAS.nii.gz /data/fs/rechuv/mri/aparc+aseg.dk.RAS.RO.nii.gz
# dwiextract -force -bzero /data/fs/rechuv/dwi/preproc.mif /data/fs/rechuv/dwi/bzero.mif >> /data/fs/rechuv/dwi/log.txt 2>&1
# mrconvert -force /data/fs/rechuv/dwi/bzero.mif /data/fs/rechuv/dwi/bzero.nii.gz
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] copying from "/data/fs/rechuv/dwi/bzero.mif" to "/data/fs/rechuv/dwi/bzero.nii.gz"[0K
# mrconvert: [100%] compressing image "/data/fs/rechuv/dwi/bzero.nii.gz"[0K
# mri_convert -rt nearest --out_orientation RAS /data/fs/rechuv/mri/T1.mgz /data/fs/rechuv/mri/T1.RAS.nii.gz
# mri_convert -rt nearest --out_orientation RAS /data/fs/rechuv/mri/T1.mgz /data/fs/rechuv/mri/T1.RAS.nii.gz
# reading from /data/fs/rechuv/mri/T1.mgz...
# TR=0.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-1, -3.00867e-11, -9.31323e-10)
# j_ras = (-9.31323e-10, 7.46431e-09, -1)
# k_ras = (-1.11429e-10, 1, -7.46587e-09)
# Setting output orientation to RAS
# Reslicing using nearest
# writing to /data/fs/rechuv/mri/T1.RAS.nii.gz...
# fslreorient2std /data/fs/rechuv/mri/T1.RAS.nii.gz /data/fs/rechuv/mri/T1.RAS.RO.nii.gz
# flirt -ref /data/fs/rechuv/dwi/bzero.nii.gz \
#     -in /data/fs/rechuv/mri/T1.RAS.RO.nii.gz \
#     -omat /data/fs/rechuv/dwi/t2d.mat \
#     -out /data/fs/rechuv/dwi/T1_in_bzero.nii.gz \
#     -cost mutualinfo -dof 12 -searchrz -180 180 -searchry -180 180  -searchrx -180 180 >> /data/fs/rechuv/dwi/log.txt 2>&1
# flirt -applyxfm -interp nearestneighbour \
#     -in /data/fs/rechuv/mri/aparc+aseg.dk.RAS.RO.nii.gz  \
#     -ref /data/fs/rechuv/dwi/bzero.nii.gz \
#     -init /data/fs/rechuv/dwi/t2d.mat -out /data/fs/rechuv/dwi/aparc+aseg.dk.nii.gz >> /data/fs/rechuv/dwi/log.txt 2>&1
# cp `find  -name fs_default.txt | head -n 1` /data/fs/rechuv/dwi/lut.dk.txt >> /data/fs/rechuv/dwi/log.txt 2>&1
# make: *** [/work/tvb-pipeline/make/Diffusion.mk:91: /data/fs/rechuv/dwi/lut.dk.txt] Error 1
# make: Leaving directory '/work/tvb-pipeline'

# %%
3
# Out:
# 3
